# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
house_df=pd.read_csv('/content/kc_house_data.csv')
house_df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house_df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
house_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,5))
sns.histplot(house_df['price'],kde=True,color='red')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.countplot(data=house_df,x=house_df['bedrooms'],hue=house_df['bedrooms'],palette='pastel',legend=False)
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
fig=plt.figure(figsize=(12,4))
sns.countplot(data=house_df,x=house_df['bathrooms'])
# Out:
# <Axes: xlabel='bathrooms', ylabel='count'>

# %%
house_df.corr()['price'].sort_values(ascending=False)
# Out:
# <ipython-input-162-9fd28a6e581d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   house_df.corr()['price'].sort_values(ascending=False)
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(12,12))
sns.heatmap(data=house_df.corr(),annot=True,fmt=".2f",cmap='coolwarm')
plt.title("Correlation Heatmap")
# Out:
# <ipython-input-163-0e0cf50e5802>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=house_df.corr(),annot=True,fmt=".2f",cmap='coolwarm')
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
price_corr=house_df.corr()['price'].sort_values(ascending=False)
price_corr
# Out:
# <ipython-input-164-76e9f9dab935>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   price_corr=house_df.corr()['price'].sort_values(ascending=False)
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %%
sns.heatmap(price_corr.to_frame(),annot=True,fmt=".2f")
plt.title("Price vs Others Correlation")
# Out:
# Text(0.5, 1.0, 'Price vs Others Correlation')

# %%
fig=plt.figure(figsize=(6,6))
sns.scatterplot(house_df,x="sqft_living",y='price')
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
fig=plt.figure(figsize=(12,8))
sns.scatterplot(house_df,y="lat",x='price')
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %%
fig=plt.figure(figsize=(12,8))
sns.scatterplot(house_df,y="long",x='price')
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
fig=plt.figure(figsize=(12,8))
sns.scatterplot(house_df,x="long",y='lat',hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,10))

sns.boxplot(data=house_df,x='bedrooms',y='price',color='green',ax=axes[0])
axes[0].set_title('Price inflation with Bedrooms')
sns.boxplot(data=house_df,x='bathrooms',y='price',color='lightblue',ax=axes[1])
axes[0].set_title('Price inflation with Bathrooms')
plt.tight_layout()

# %%
price_sorted_df=house_df.sort_values(by='price',ascending=False)

# %%
len(price_sorted_df)
# Out:
# 21613

# %%
len(price_sorted_df)*0.01
# Out:
# 216.13

# %%
not_top_1_df=pd.DataFrame(price_sorted_df.iloc[216:])

# %%
fig=plt.figure(figsize=(10,6))
sns.scatterplot(not_top_1_df,x='long',y='lat',hue='price',palette='flare')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
fig=plt.figure(figsize=(10,6))
sns.boxplot(data=not_top_1_df,x='waterfront',y='price')
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
house_df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house_df.drop('id',axis=1,inplace=True)

# %%
house_df['date']
# Out:
# 0        20141013T000000
# 1        20141209T000000
# 2        20150225T000000
# 3        20141209T000000
# 4        20150218T000000
#               ...
# 21608    20140521T000000
# 21609    20150223T000000
# 21610    20140623T000000
# 21611    20150116T000000
# 21612    20141015T000000
# Name: date, Length: 21613, dtype: object

# %%
house_df['date']=pd.to_datetime(house_df['date'],format='%Y%m%dT%H%M%S')

# %%
house_df['month']=house_df['date'].apply(lambda date: date.month)

# %%
house_df['year']=house_df['date'].apply(lambda date: date.year)

# %%
house_df.drop('date',axis=1,inplace=True)

# %%
sns.boxplot(data=house_df,x='month',y='price')
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
house_df.groupby('month').mean()['price'].plot()
# Out:
# <Axes: xlabel='month'>

# %%
house_df.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
house_df.drop('zipcode',axis=1,inplace=True)

# %%
house_df['yr_renovated'].value_counts()
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
house_df['sqft_basement'].value_counts()
# Out:
# 0      13126
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
X=house_df.drop('price',axis=1).values
y=house_df['price'].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model=Sequential()

# %%
model.add(Dense(15,activation='relu'))
model.add(Dense(15,activation='relu'))
model.add(Dense(15,activation='relu'))
model.add(Dense(15,activation='relu'))
model.add(Dense(15,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='rmsprop',loss='mse')

# %%
model.fit(X_train,y_train,epochs=400,validation_data=(X_test,y_test),batch_size=128)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 5ms/step - loss: 419699949568.0000 - val_loss: 442250821632.0000
# Epoch 2/400
# 119/119 [==============================] - 1s 5ms/step - loss: 419623829504.0000 - val_loss: 442038714368.0000
# Epoch 3/400
# 119/119 [==============================] - 1s 4ms/step - loss: 419011788800.0000 - val_loss: 440745820160.0000
# Epoch 4/400
# 119/119 [==============================] - 1s 4ms/step - loss: 416325238784.0000 - val_loss: 435900022784.0000
# Epoch 5/400
# 119/119 [==============================] - 1s 5ms/step - loss: 407951671296.0000 - val_loss: 422511411200.0000
# Epoch 6/400
# 119/119 [==============================] - 1s 4ms/step - loss: 387562799104.0000 - val_loss: 392429797376.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 3ms/step - loss: 345954877440.0000 - val_loss: 335983378432.0000
# Epoch 8/400
# ...

# %%
loss_df=pd.DataFrame(model.history.history)

# %%
X_train.shape
# Out:
# (15129, 19)

# %%
loss_df.plot()
# Out:
# <Axes: >

# %%
model.evaluate(X_train,y_train)
# Out:
# 473/473 [==============================] - 1s 2ms/step - loss: 22187233280.0000
# 22187233280.0

# %%
model.evaluate(X_test,y_test)
# Out:
# 203/203 [==============================] - 0s 1ms/step - loss: 28142895104.0000
# 28142895104.0

# %%
predicted_values=model.predict(X_test)
# Out:
# 203/203 [==============================] - 0s 2ms/step

# %%
predicted_df=pd.DataFrame(predicted_values,columns=['predicted_price'])
predicted_df.head()
# Out:
#    predicted_price
# 0     3.966076e+05
# 1     7.723836e+05
# 2     1.151354e+06
# 3     2.184398e+06
# 4     7.360079e+05

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score
np.sqrt(mean_squared_error(predicted_values,y_test))
# Out:
# 167758.4446132727

# %%
mean_absolute_error=mean_absolute_error(predicted_values,y_test)

# %%
house_df['price'].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
diff_in_prices=(mean_absolute_error/5.400881e+05)*100
round(diff_in_prices,2)
# Out:
# 17.87

# %%
explained_variance_score(y_test,predicted_values)
# Out:
# 0.8050619812406639

# %%
true_df=pd.DataFrame(y_test,columns=['true_price'])
true_df.head()
# Out:
#    true_price
# 0    365000.0
# 1    865000.0
# 2   1038000.0
# 3   1490000.0
# 4    711000.0

# %%
predicted_df=pd.concat([predicted_df,true_df],axis=1)

# %%
predicted_df.columns
# Out:
# Index(['predicted_price', 'true_price'], dtype='object')

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(12,6))
sns.scatterplot(x='true_price',y='predicted_price',data=predicted_df)
plt.plot(y_test,y_test,color='r')

# %%
predicted_df.sort_values(by='true_price',ascending=False)
# Out:
#       predicted_price  true_price
# 2232     4.423902e+06   5570000.0
# 1979     3.728317e+06   5350000.0
# 5039     4.573104e+06   5300000.0
# 4177     4.304047e+06   4500000.0
# 3195     3.096245e+06   4000000.0
# ...               ...         ...
# 885      1.768194e+05     89000.0
# 5861     2.138493e+05     85000.0
# 3430     2.368106e+05     83000.0
# 1269     2.360272e+05     82500.0
# 4869     2.704802e+05     78000.0
#
# [6484 rows x 2 columns]

# %%
house_df.sort_values(by='price',ascending=False)
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7252   7700000.0         6       8.00        12050     27600     2.5
# 3914   7062500.0         5       4.50        10040     37325     2.0
# 9254   6885000.0         6       7.75         9890     31374     2.0
# 4411   5570000.0         5       5.75         9200     35069     2.0
# 1448   5350000.0         5       5.00         8000     23985     2.0
# ...          ...       ...        ...          ...       ...     ...
# 8274     82000.0         3       1.00          860     10426     1.0
# 16198    81000.0         2       1.00          730      9975     1.0
# 465      80000.0         1       0.75          430      5050     1.0
# 15293    78000.0         2       1.00          780     16344     1.0
# 1149     75000.0         1       0.00          670     43377     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# # **SECOND MODEL**

# %%
not_top_2_df=pd.DataFrame(price_sorted_df.iloc[3:])

# %%
not_top_2_df.head()
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 4411         9200     35069     2.0           0     0  ...     13        6200
# 1448         8000     23985     2.0           0     4  ...     12        6720
# 1315         7390     24829     2.0           1     4  ...     12        5000
# 1164         8010     45517     2.0           1     4  ...     12        5990
# 8092         9640     13068     1.0           1     4  ...     12        4820
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
fig=plt.figure(figsize=(12,6))
sns.heatmap(not_top_2_df.corr(),annot=True,fmt=".2f",cmap='coolwarm')
# Out:
# <ipython-input-129-46867084a88a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(not_top_2_df.corr(),annot=True,fmt=".2f",cmap='coolwarm')
# <Axes: >

# %%
corr_not_top_2=not_top_2_df.corr()['price'].sort_values(ascending=False)
corr_not_top_2
# Out:
# <ipython-input-130-6afd63bfe4ee>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_not_top_2=not_top_2_df.corr()['price'].sort_values(ascending=False)
# price            1.000000
# sqft_living      0.693761
# grade            0.677192
# sqft_above       0.597950
# sqft_living15    0.597436
# bathrooms        0.519261
# view             0.395120
# lat              0.321596
# sqft_basement    0.312313
# bedrooms         0.311805
# floors           0.265307
# waterfront       0.246126
# yr_renovated     0.124579
# sqft_lot         0.091997
# sqft_lot15       0.084137
# yr_built         0.053802
# condition        0.040580
# long             0.024696
# id              -0.022049
# zipcode         -0.051336
# Name: price, dtype: float64

# %%
sns.heatmap(corr_not_top_2.to_frame(),annot=True,fmt=".2f",cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.countplot(data=not_top_2_df,x='grade')
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
sns.catplot(data=not_top_2_df,x='grade',y='price')

# %%
not_top_2_df.head()
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 16302  7397300170  20140530T000000  3710000.0         4       3.50
# 6508   4217402115  20150421T000000  3650000.0         6       4.75
# 18482  4389201095  20150511T000000  3650000.0         5       3.75
# 15255  2425049063  20140911T000000  3640900.0         4       3.25
# 19148  3625049042  20141011T000000  3635000.0         5       6.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 16302         5550     28078     2.0           0     2  ...     12
# 6508          5480     19401     1.5           1     4  ...     11
# 18482         5020      8694     2.0           0     1  ...     12
# 15255         4830     22257     2.0           1     4  ...     11
# 19148         5490     19897     2.0           0     0  ...     12
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 16302        3350           2200      2000             0    98039  47.6395
# ...

# %%
sns.scatterplot(not_top_2_df,x='sqft_living',y='price')
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
sns.scatterplot(not_top_2_df,y='sqft_living15',x='price')
# Out:
# <Axes: xlabel='price', ylabel='sqft_living15'>

# %%
not_top_2_df.head()
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 4411         9200     35069     2.0           0     0  ...     13        6200
# 1448         8000     23985     2.0           0     4  ...     12        6720
# 1315         7390     24829     2.0           1     4  ...     12        5000
# 1164         8010     45517     2.0           1     4  ...     12        5990
# 8092         9640     13068     1.0           1     4  ...     12        4820
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
not_top_2_df['date']
# Out:
# 2085     20141114T000000
# 19017    20140911T000000
# 7035     20140701T000000
# 16302    20140530T000000
# 6508     20150421T000000
#               ...
# 8274     20141105T000000
# 16198    20150324T000000
# 465      20140523T000000
# 15293    20140506T000000
# 1149     20150217T000000
# Name: date, Length: 21601, dtype: object

# %%
not_top_2_df['date']=pd.to_datetime(not_top_2_df['date'])

# %%
not_top_2_df['month']=not_top_2_df['date'].apply(lambda date: date.month)
not_top_2_df['year']=not_top_2_df['date'].apply(lambda date: date.year)
not_top_2_df
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 4411   2470100110 2014-08-04  5570000.0         5       5.75         9200
# 1448   8907500070 2015-04-13  5350000.0         5       5.00         8000
# 1315   7558700030 2015-04-13  5300000.0         6       6.00         7390
# 1164   1247600105 2014-10-20  5110800.0         5       5.25         8010
# 8092   1924059029 2014-06-17  4668000.0         5       6.75         9640
# ...           ...        ...        ...       ...        ...          ...
# 8274   3883800011 2014-11-05    82000.0         3       1.00          860
# 16198  3028200080 2015-03-24    81000.0         2       1.00          730
# 465    8658300340 2014-05-23    80000.0         1       0.75          430
# 15293    40000362 2014-05-06    78000.0         2       1.00          780
# 1149   3421079032 2015-02-17    75000.0         1       0.00          670
#
#        sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# ...

# %%
not_top_2_df.drop('zipcode',axis=1,inplace=True)

# %%
not_top_2_df.drop('date',axis=1,inplace=True)

# %%
not_top_2_df.drop('id',axis=1,inplace=True)

# %%
not_top_2_df
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 4411   5570000.0         5       5.75         9200     35069     2.0
# 1448   5350000.0         5       5.00         8000     23985     2.0
# 1315   5300000.0         6       6.00         7390     24829     2.0
# 1164   5110800.0         5       5.25         8010     45517     2.0
# 8092   4668000.0         5       6.75         9640     13068     1.0
# ...          ...       ...        ...          ...       ...     ...
# 8274     82000.0         3       1.00          860     10426     1.0
# 16198    81000.0         2       1.00          730      9975     1.0
# 465      80000.0         1       0.75          430      5050     1.0
# 15293    78000.0         2       1.00          780     16344     1.0
# 1149     75000.0         1       0.00          670     43377     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
not_top_2_df.groupby('month').mean()['price'].plot()
# Out:
# <Axes: xlabel='month'>

# %%
not_top_2_df.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
X=not_top_2_df.drop('price',axis=1).values
y=not_top_2_df['price'].values

# %%
X
# Out:
# array([[5.0000e+00, 5.7500e+00, 9.2000e+03, ..., 2.4345e+04, 8.0000e+00,
#         2.0140e+03],
#        [5.0000e+00, 5.0000e+00, 8.0000e+03, ..., 2.1750e+04, 4.0000e+00,
#         2.0150e+03],
#        [6.0000e+00, 6.0000e+00, 7.3900e+03, ..., 2.4619e+04, 4.0000e+00,
#         2.0150e+03],
#        ...,
#        [1.0000e+00, 7.5000e-01, 4.3000e+02, ..., 7.5000e+03, 5.0000e+00,
#         2.0140e+03],
#        [2.0000e+00, 1.0000e+00, 7.8000e+02, ..., 1.0387e+04, 5.0000e+00,
#         2.0140e+03],
#        [1.0000e+00, 0.0000e+00, 6.7000e+02, ..., 4.2882e+04, 2.0000e+00,
#         2.0150e+03]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit_transform(X_train)
scaler.transform(X_test)
# Out:
# array([[4.00000000e-01, 3.07692308e-01, 2.18377088e-01, ...,
#         8.18908528e-03, 1.81818182e-01, 1.00000000e+00],
#        [3.00000000e-01, 2.30769231e-01, 1.05011933e-01, ...,
#         9.13676312e-03, 1.00000000e+00, 0.00000000e+00],
#        [2.00000000e-01, 3.46153846e-01, 1.09785203e-01, ...,
#         8.01792892e-04, 6.36363636e-01, 0.00000000e+00],
#        ...,
#        [4.00000000e-01, 3.07692308e-01, 2.15990453e-01, ...,
#         3.73212766e-03, 9.09090909e-01, 0.00000000e+00],
#        [5.00000000e-01, 3.84615385e-01, 2.72076372e-01, ...,
#         9.67665232e-03, 4.54545455e-01, 0.00000000e+00],
#        [4.00000000e-01, 3.46153846e-01, 2.11217184e-01, ...,
#         5.16984110e-02, 1.81818182e-01, 1.00000000e+00]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model=Sequential()
model.add(Dense(15,activation='relu'))
model.add(Dense(15,activation='relu'))
model.add(Dense(15,activation='relu'))
model.add(Dense(15,activation='relu'))

model.add(Dense(1))

# %%
model.compile(optimizer='adam',loss='mse')

# %%
model.fit(X_train,y_train,batch_size=128,epochs=400,validation_data=(X_test,y_test))
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 3ms/step - loss: 387855187968.0000 - val_loss: 315249917952.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 2ms/step - loss: 254120902656.0000 - val_loss: 178790858752.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 2ms/step - loss: 106288201728.0000 - val_loss: 79107547136.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 2ms/step - loss: 75269038080.0000 - val_loss: 72651800576.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 2ms/step - loss: 71359389696.0000 - val_loss: 69243895808.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 2ms/step - loss: 68182278144.0000 - val_loss: 66494894080.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 2ms/step - loss: 65353236480.0000 - val_loss: 63247081472.0000
# Epoch 8/400
# ...

# %%
loss_df=pd.DataFrame(model.history.history)

# %%
fig=plt.figure(figsize=(10,6))
loss_df.plot()
# Out:
# <Axes: >

# %%
predicted=model.predict(X_test)
# Out:
# 203/203 [==============================] - 0s 853us/step

# %%
from sklearn.metrics import mean_absolute_error,explained_variance_score,mean_squared_error

# %%
np.sqrt(mean_squared_error(predicted,y_test))
# Out:
# 205587.69034304423

# %%
explained_variance_score(predicted,y_test)
# Out:
# 0.4465367588442247

# %%
mean_absolute_error(y_test,predicted)
# Out:
# 137560.18728780863

# %%
y_test
# Out:
# array([285000., 157000., 461100., ..., 550000., 492500., 500000.])

# %%
predicted
# Out:
# array([[390653.66],
#        [278905.8 ],
#        [435251.34],
#        ...,
#        [625023.8 ],
#        [637242.44],
#        [442678.34]], dtype=float32)

# %%
fig=plt.figure(figsize=(10,6))
plt.scatter(y_test,predicted)
plt.scatter(y_test,y_test,color='r')
